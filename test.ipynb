# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('re360_test.csv', index_col=0)

# %%
df.head()
# Out:
#                           property_address  \
# 305  110 HIGH PARK PL PITTSBURGH, PA 15206
# 306  115 HIGH PARK PL PITTSBURGH, PA 15206
# 307  116 HIGH PARK PL PITTSBURGH, PA 15206
# 308  121 HIGH PARK PL PITTSBURGH, PA 15206
# 309  122 HIGH PARK PL PITTSBURGH, PA 15206
#
#                              owner_name  \
# 305  STAPINSKI BERNARD A & ROSE ANN (W)
# 306                         ANALO HELEN
# 307      MCDERMOTT KEVIN P DEWEESE NEIL
# 308      MOTLEY THOMAS A & LILLIE M (W)
# 309    FARINO S LOUIS & CATHERINE J (W)
#
#                                    owner_mailing  sale_date sale_price  \
# 305  110 HIGH PARK PL PITTSBURGH , PA 15206-1160  10/6/1999   $162,000
# 306   608 GLENGARY DR PITTSBURGH , PA 15215-1108  6/26/2018   $448,000
# 307  116 HIGH PARK PL PITTSBURGH , PA 15206-1160  11/2/2009   $242,500
# 308  121 HIGH PARK PL PITTSBURGH , PA 15206-1159  8/27/1985   $131,000
# 309  122 HIGH PARK PL PITTSBURGH , PA 15206-1160   1/5/1971         $0
#
# ...

# %%
df[~df['property_address'].str.contains('high park|walnut', case=False)].reset_index(drop=True).to_clipboard()
